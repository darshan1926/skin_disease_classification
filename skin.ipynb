# %% [markdown]
# # MACHINE LEARNING HACKATHON 2019
# ## TEAM EASY COMPANY

# %% [markdown]
# ---

# %% [markdown]
# ### _PROBLEM STATEMENT:-_

# %% [markdown]
# Predicting the different types of skin cancer like Melanocytic nevi, Actinic keratoses etc using Convolution Neural Network(CNN) which otherwise would have been diagnosed by expensive and time consuming methods like Histopathology, Confocal microscopy etc

# %% [markdown]
# ## _INTRODUCTION:-_

# %% [markdown]
# As skin cancer is one of the most frequent cancers globally, accurate, non-invasive dermoscopy-based diagnosis becomes essential and promising. Our task is to predict seven disease classes with skin lesion images, including melanoma (MEL), melanocytic nevus (NV), basal cell carcinoma (BCC), actinic keratosis / Bowens disease (intraepithelial carcinoma) (AKIEC), benign keratosis (solar lentigo / seborrheic keratosis / lichen planus-like keratosis)(BKL), dermatofibroma (DF) and vascular lesion (VASC).

# %% [markdown]
# - **Melanocytic nevi**
# - **Melanoma**
# - **Benign keratosis-like lesions**
# - **Basal cell carcinoma**
# - **Actinic keratoses**
# - **Vascular lesions**
# - **Dermatofibroma**

# %% [markdown]
# ## _Dataset information_

# %% [markdown]
# Dermoscopic lesion images were acquired from HAM10000
# Dataset. A disease label for each image was determined histopathologically or diagnostically. A
# training dataset for classification consisted of 10,015 images (327 AKIEC, 514 BCC, 1,099 BKL, 115 DF, 1,113 MEL, 6,705 NV,and 142 VASC samples) with the corresponding disease label (ground truth), and a validation set and a test set.

# %% [markdown]
# [Dataset](https://www.kaggle.com/kmader/skin-cancer-mnist-ham10000)

# %% [markdown]
# # _STEP 1: Importing Essential Libraries_

# %%
import numpy as np
import pandas as pd
import os
from glob import glob
import keras
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from PIL import Image
np.random.seed(123)
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Step 2: _Data processing_

# %%
imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x
              for x in glob(os.path.join('', '*', '*.jpg'))}
lesion_dict = {     
                  'nv': 'Melanocytic nevi',
                  'mel': 'Melanoma',
                  'bkl': 'Benign keratosis-like lesions ',
                  'bcc': 'Basal cell carcinoma',
                  'akiec': 'Actinic keratoses',
                  'vasc': 'Vascular lesions',
                  'df': 'Dermatofibroma'
              }

# %% [markdown]
# ### __Reading Dataset and adding new columns:__

# %%
dataset = pd.read_csv('HAM10000_metadata.csv')

dataset['path'] = dataset['image_id'].map(imageid_path_dict.get)
dataset['cell_type'] = dataset['dx'].map(lesion_dict.get)
dataset['cell_codes'] = pd.Categorical(dataset['cell_type']).codes

# %%
dataset.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                        path                       cell_type  cell_codes
# 0  dataset\ISIC_0027419.jpg  Benign keratosis-like lesions            2
# 1  dataset\ISIC_0025030.jpg  Benign keratosis-like lesions            2
# 2  dataset\ISIC_0026769.jpg  Benign keratosis-like lesions            2
# 3  dataset\ISIC_0025661.jpg  Benign keratosis-like lesions            2
# 4  dataset\ISIC_0031633.jpg  Benign keratosis-like lesions            2

# %% [markdown]
# ## _Step 3:- Data Cleaning_

# %%
dataset.isnull().sum()
# Out:
# lesion_id        0
# image_id         0
# dx               0
# dx_type          0
# age             57
# sex              0
# localization     0
# path             0
# cell_type        0
# cell_codes       0
# dtype: int64

# %%
dataset['age'].fillna((dataset['age'].mean()), inplace=True)

# %%
dataset.isnull().sum()
# Out:
# lesion_id       0
# image_id        0
# dx              0
# dx_type         0
# age             0
# sex             0
# localization    0
# path            0
# cell_type       0
# cell_codes      0
# dtype: int64

# %% [markdown]
# ## **_Visualisations_**

# %%
def DIE():
    
    from IPython.display import HTML
    from IPython.display import display

    tag = HTML('''<script>
    code_show=true; 
    function code_toggle() 
    {
        if (code_show)
        {
            $('div.cell.code_cell.rendered.selected div.input').hide();
        } else 
        {
            $('div.cell.code_cell.rendered.selected div.input').show();
        }
        code_show = !code_show
    } 
    $( document ).ready(code_toggle);
    </script>
    <a href="javascript:code_toggle()">CODE</a>.''')
    display(tag)
DIE()
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### _Cell type count bar diagram_

# %%
DIE()
fig, ax1 = plt.subplots(1, 1, figsize = (20, 10))
dataset['cell_type'].value_counts().plot(kind='bar', ax = ax1)
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.
# <AxesSubplot:>

# %% [markdown]
# ### _Method count bar diagram_

# %%
DIE()
fig, ax1 = plt.subplots(1, 1, figsize= (20, 10))
dataset['dx_type'].value_counts().plot(kind='bar')
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.
# <AxesSubplot:>

# %% [markdown]
# ### _Region count bar diagram_

# %%
DIE()
fig, ax1 = plt.subplots(1, 1, figsize= (25, 15))
dataset['localization'].value_counts().plot(kind='bar')
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.
# <AxesSubplot:>

# %% [markdown]
# ### _Age count histogram_

# %%
DIE()
fig, ax1 = plt.subplots(1, 1, figsize= (25, 15))
dataset['age'].hist(bins=40)
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.
# <AxesSubplot:>

# %% [markdown]
# ### _Cell type count histogram_

# %%
DIE()
fig, ax1 = plt.subplots(1, 1, figsize= (25, 15))
dataset['cell_codes'].hist(bins=40)
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.
# <AxesSubplot:>

# %% [markdown]
# ### _Step 4:-Resizing the images:-_

# %% [markdown]
# In this step images will be loaded into the column named image from the image path from the image folder. We also resize the images as the original dimension of images are 450 x 600 x3 which TensorFlow can't handle, so that's why we resize it into 64 x 64.

# %%
dataset['image'] = dataset['path'].map(lambda x: np.asarray(Image.open(x).resize((64,64))))

# %%
dataset.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                        path                       cell_type  cell_codes  \
# 0  dataset\ISIC_0027419.jpg  Benign keratosis-like lesions            2
# 1  dataset\ISIC_0025030.jpg  Benign keratosis-like lesions            2
# 2  dataset\ISIC_0026769.jpg  Benign keratosis-like lesions            2
# 3  dataset\ISIC_0025661.jpg  Benign keratosis-like lesions            2
# 4  dataset\ISIC_0031633.jpg  Benign keratosis-like lesions            2
#
#                                                image
# 0  [[[191, 152, 194], [191, 153, 195], [192, 149,...
# 1  [[[23, 13, 23], [25, 14, 28], [37, 24, 46], [6...
# 2  [[[186, 129, 140], [192, 136, 151], [198, 143,...
# 3  [[[24, 11, 19], [36, 20, 30], [64, 38, 50], [9...
# 4  [[[139, 95, 118], [158, 114, 138], [178, 133, ...

# %% [markdown]
# ### _Step 5:- Displaying Samples_

# %%
DIE()
import matplotlib.pyplot as plt
fig, m_axs = plt.subplots(7, 4, figsize = (4*4, 3*7))
for n_axs, (type_name, type_rows) in zip(m_axs,dataset.sort_values(['cell_type']).groupby('cell_type')):
    n_axs[0].set_title(type_name)
    for c_ax, (_, c_row) in zip(n_axs, type_rows.sample(7, random_state=1).iterrows()):
        c_ax.imshow(c_row['image'])
        c_ax.axis('off')
fig.savefig('category_samples.png', dpi=300)
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.

# %% [markdown]
# ### _Step 6:- Selecting the features and targets_

# %%
features=dataset.drop(columns=['cell_codes'],axis=1)
target=dataset['cell_codes']

# %% [markdown]
# ### _Step 5:- Train test splitting_

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(features, target, test_size=0.20,random_state=2)

# %% [markdown]
# ### _Step 6:- Normalising the training set_

# %% [markdown]
# Normalisation reduces data redundancy.It is a process to eliminate the flaws of a database with bad design. A poorly designed database is inconsistent and create issues while adding, deleting or updating information.

# %%
x_train = np.asarray(x_train1['image'].tolist())
x_test = np.asarray(x_test1['image'].tolist())

x_train_mean = np.mean(x_train)
x_train_std = np.std(x_train)

x_test_mean = np.mean(x_test)
x_test_std = np.std(x_test)

x_train = (x_train - x_train_mean)/x_train_std
x_test = (x_test - x_test_mean)/x_test_std

# %% [markdown]
# ### _Step 7:- Performing one-hot encoding on the labels_

# %%
y_train = to_categorical(y_train1, num_classes = 7)
y_test = to_categorical(y_test1, num_classes = 7)

# %% [markdown]
# ### _Step 8:- Validation and training set splitting_

# %%
x_train, x_validate, y_train, y_validate = train_test_split(x_train, y_train, test_size = 0.1, random_state = 2)

# %% [markdown]
# ### _Step 9:- Reshaping image in 4 dimensions_

# %%
x_train = x_train.reshape(x_train.shape[0], *(64, 64, 3))
x_test = x_test.reshape(x_test.shape[0], *(64, 64, 3))
x_validate = x_validate.reshape(x_validate.shape[0], *(64, 64, 3))

# %% [markdown]
# ## _CNN_
# ### _USING KERAS TENSORFLOW IN BACKEND_

# %% [markdown]
# ---

# %% [markdown]
# In this model, we first appply different feature detectors or kernels onto the input image to get the first two convoled layers then we apply Max Pooling to get the max pooled layer and similiarly we obtain the next layers and finally we obtain the Flatten layer using Flatten(). Then the fully connected layers(hidden layers) to finally give the output layer of 7 neurons.

# %% [markdown]
# ![title](https://www.researchgate.net/profile/Xiaofei_Yang26/publication/324575020/figure/fig1/AS:672197303615489@1537275734069/The-CNN-model-consisting-of-convolution-layers-pooling-layers-and-full-connection-layer.png)

# %%
shape = (64, 64, 3)

classifier = Sequential()
classifier.add(Conv2D(32, (3, 3), activation='relu',input_shape=shape))
classifier.add(Conv2D(32, (3, 3), activation='relu'))
classifier.add(MaxPool2D(pool_size = (2, 2)))
classifier.add(Dropout(0.05))

classifier.add(Conv2D(64, (3, 3), activation='relu'))
classifier.add(Conv2D(64, (3, 3), activation='relu'))
classifier.add(MaxPool2D(pool_size=(2, 2)))
classifier.add(Dropout(0.10))

classifier.add(Flatten())

classifier.add(Dense(128, activation='relu'))
classifier.add(Dropout(0.15))
classifier.add(Dense(64, activation='relu'))

classifier.add(Dense(32, activation='relu'))
classifier.add(Dropout(0.20))

classifier.add(Dense(7, activation='softmax'))
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 30, 30, 32)       0
#  )
#
#  dropout (Dropout)           (None, 30, 30, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 13, 13, 64)        0
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dense (Dense)               (None, 128)               1384576
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 1,460,711
# Trainable params: 1,460,711
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### _Step 10:- Compiling the model_

# %%
classifier.compile(optimizer = 'adam' , loss = "categorical_crossentropy", metrics=["accuracy"])

# %% [markdown]
# #### _Categorical Cross Entropy_

# %% [markdown]
# Categorical cross entropy is a Softmax activation plus a Cross-Entropy loss. While using this loss, we train a CNN to output a probability over the C classes for each image. It is used for multi-class classification.

# %% [markdown]
# ![title](https://gombru.github.io/assets/cross_entropy_loss/softmax_CE_pipeline.png)

# %% [markdown]
# ### _Step 12:- Image Augmentation_

# %%
datagen = ImageDataGenerator(
                            featurewise_std_normalization=False, 
                            samplewise_std_normalization=False, 
                            rotation_range=10, 
                            zoom_range = 0.1,  
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            horizontal_flip=False,  
                            vertical_flip=False
                            )
datagen.fit(x_train)

# %% [markdown]
# ### _Step 13:- Fitting the model_

# %%
epochs = 50
batch_size = 100
history = classifier.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_validate,y_validate),
                              steps_per_epoch=x_train.shape[0] // batch_size)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6056\1295825522.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = classifier.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
# Epoch 1/50
# 72/72 [==============================] - 186s 2s/step - loss: 1.0684 - accuracy: 0.6605 - val_loss: 0.8782 - val_accuracy: 0.6696
# Epoch 2/50
# 72/72 [==============================] - 96s 1s/step - loss: 0.9325 - accuracy: 0.6653 - val_loss: 0.8681 - val_accuracy: 0.6870
# Epoch 3/50
# 72/72 [==============================] - 95s 1s/step - loss: 0.8987 - accuracy: 0.6757 - val_loss: 0.8471 - val_accuracy: 0.7132
# Epoch 4/50
# 72/72 [==============================] - 95s 1s/step - loss: 0.8600 - accuracy: 0.6861 - val_loss: 0.7719 - val_accuracy: 0.7107
# Epoch 5/50
# 72/72 [==============================] - 95s 1s/step - loss: 0.8167 - accuracy: 0.7014 - val_loss: 0.7585 - val_accuracy: 0.7195
# Epoch 6/50
# 72/72 [==============================] - 96s 1s/step - loss: 0.7953 - accuracy: 0.7128 - val_loss: 0.7182 - val_accuracy: 0.7382
# Epoch 7/50
# 72/72 [==============================] - 98s 1s/step - loss: 0.7621 - accuracy: 0.7176 - val_loss: 0.6796 - val_accuracy: 0.7668
# Epoch 8/50
# 72/72 [==============================] - 94s 1s/step - loss: 0.7437 - accuracy: 0.7286 - val_loss: 0.6893 - val_accuracy: 0.7569
# Epoch 9/50
# 72/72 [==============================] - 94s 1s/step - loss: 0.7235 - accuracy: 0.7316 - val_loss: 0.6648 - val_accuracy: 0.7431
# Epoch 10/50
# 72/72 [==============================] - 94s 1s/step - loss: 0.7193 - accuracy: 0.7392 - val_loss: 0.6644 - val_accuracy: 0.7731
# Epoch 11/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.7032 - accuracy: 0.7402 - val_loss: 0.6626 - val_accuracy: 0.7606
# Epoch 12/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.7015 - accuracy: 0.7480 - val_loss: 0.6526 - val_accuracy: 0.7693
# Epoch 13/50
# 72/72 [==============================] - 98s 1s/step - loss: 0.6821 - accuracy: 0.7515 - val_loss: 0.6597 - val_accuracy: 0.7643
# Epoch 14/50
# 72/72 [==============================] - 94s 1s/step - loss: 0.6816 - accuracy: 0.7495 - val_loss: 0.6694 - val_accuracy: 0.7544
# Epoch 15/50
# 72/72 [==============================] - 94s 1s/step - loss: 0.6692 - accuracy: 0.7529 - val_loss: 0.6959 - val_accuracy: 0.7406
# Epoch 16/50
# 72/72 [==============================] - 95s 1s/step - loss: 0.6551 - accuracy: 0.7577 - val_loss: 0.6230 - val_accuracy: 0.7843
# Epoch 17/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.6391 - accuracy: 0.7650 - val_loss: 0.6046 - val_accuracy: 0.7718
# Epoch 18/50
# 72/72 [==============================] - 94s 1s/step - loss: 0.6386 - accuracy: 0.7681 - val_loss: 0.6280 - val_accuracy: 0.7718
# Epoch 19/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.6196 - accuracy: 0.7729 - val_loss: 0.6257 - val_accuracy: 0.7743
# Epoch 20/50
# 72/72 [==============================] - 94s 1s/step - loss: 0.6333 - accuracy: 0.7648 - val_loss: 0.6204 - val_accuracy: 0.7830
# Epoch 21/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.6045 - accuracy: 0.7789 - val_loss: 0.6078 - val_accuracy: 0.7805
# Epoch 22/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.6020 - accuracy: 0.7796 - val_loss: 0.6032 - val_accuracy: 0.7805
# Epoch 23/50
# 72/72 [==============================] - 92s 1s/step - loss: 0.6004 - accuracy: 0.7743 - val_loss: 0.6125 - val_accuracy: 0.7731
# Epoch 24/50
# 72/72 [==============================] - 94s 1s/step - loss: 0.5842 - accuracy: 0.7869 - val_loss: 0.6176 - val_accuracy: 0.7855
# Epoch 25/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.5923 - accuracy: 0.7812 - val_loss: 0.6306 - val_accuracy: 0.7743
# Epoch 26/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.5934 - accuracy: 0.7827 - val_loss: 0.6038 - val_accuracy: 0.7855
# Epoch 27/50
# 72/72 [==============================] - 92s 1s/step - loss: 0.5717 - accuracy: 0.7889 - val_loss: 0.6169 - val_accuracy: 0.7905
# Epoch 28/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.5670 - accuracy: 0.7956 - val_loss: 0.6452 - val_accuracy: 0.7643
# Epoch 29/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.5474 - accuracy: 0.8008 - val_loss: 0.6339 - val_accuracy: 0.7781
# Epoch 30/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.5435 - accuracy: 0.8032 - val_loss: 0.5799 - val_accuracy: 0.8005
# Epoch 31/50
# 72/72 [==============================] - 91s 1s/step - loss: 0.5398 - accuracy: 0.7951 - val_loss: 0.5988 - val_accuracy: 0.7830
# Epoch 32/50
# 72/72 [==============================] - 91s 1s/step - loss: 0.5264 - accuracy: 0.8080 - val_loss: 0.6351 - val_accuracy: 0.7756
# Epoch 33/50
# 72/72 [==============================] - 92s 1s/step - loss: 0.5285 - accuracy: 0.8034 - val_loss: 0.6472 - val_accuracy: 0.7668
# Epoch 34/50
# 72/72 [==============================] - 92s 1s/step - loss: 0.5010 - accuracy: 0.8181 - val_loss: 0.6390 - val_accuracy: 0.7880
# Epoch 35/50
# 72/72 [==============================] - 92s 1s/step - loss: 0.5073 - accuracy: 0.8125 - val_loss: 0.6338 - val_accuracy: 0.7668
# Epoch 36/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.5153 - accuracy: 0.8138 - val_loss: 0.6032 - val_accuracy: 0.7993
# Epoch 37/50
# 72/72 [==============================] - 95s 1s/step - loss: 0.4840 - accuracy: 0.8207 - val_loss: 0.5746 - val_accuracy: 0.8092
# Epoch 38/50
# 72/72 [==============================] - 97s 1s/step - loss: 0.4836 - accuracy: 0.8221 - val_loss: 0.6070 - val_accuracy: 0.8030
# Epoch 39/50
# 72/72 [==============================] - 104s 1s/step - loss: 0.4697 - accuracy: 0.8225 - val_loss: 0.6141 - val_accuracy: 0.7905
# Epoch 40/50
# 72/72 [==============================] - 97s 1s/step - loss: 0.4670 - accuracy: 0.8295 - val_loss: 0.6212 - val_accuracy: 0.7993
# Epoch 41/50
# 72/72 [==============================] - 102s 1s/step - loss: 0.4692 - accuracy: 0.8255 - val_loss: 0.6350 - val_accuracy: 0.8017
# Epoch 42/50
# 72/72 [==============================] - 95s 1s/step - loss: 0.4753 - accuracy: 0.8278 - val_loss: 0.6391 - val_accuracy: 0.7830
# Epoch 43/50
# 72/72 [==============================] - 94s 1s/step - loss: 0.4467 - accuracy: 0.8305 - val_loss: 0.6336 - val_accuracy: 0.7968
# Epoch 44/50
# 72/72 [==============================] - 94s 1s/step - loss: 0.4628 - accuracy: 0.8250 - val_loss: 0.6573 - val_accuracy: 0.7880
# Epoch 45/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.4660 - accuracy: 0.8290 - val_loss: 0.6176 - val_accuracy: 0.7930
# Epoch 46/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.4296 - accuracy: 0.8402 - val_loss: 0.5973 - val_accuracy: 0.7706
# Epoch 47/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.4252 - accuracy: 0.8449 - val_loss: 0.6211 - val_accuracy: 0.7868
# Epoch 48/50
# 72/72 [==============================] - 93s 1s/step - loss: 0.4128 - accuracy: 0.8463 - val_loss: 0.6301 - val_accuracy: 0.7893
# Epoch 49/50
# 72/72 [==============================] - 92s 1s/step - loss: 0.4171 - accuracy: 0.8423 - val_loss: 0.6309 - val_accuracy: 0.7968
# Epoch 50/50
# 72/72 [==============================] - 92s 1s/step - loss: 0.4172 - accuracy: 0.8437 - val_loss: 0.6268 - val_accuracy: 0.7918

# %% [markdown]
# ### _Step 14:- Calculating validation set and test set accuracies_

# %%
loss, accuracy = classifier.evaluate(x_test, y_test)
loss_v, accuracy_v = classifier.evaluate(x_validate, y_validate)
print("Validation: accuracy = %f  ;  loss_v = %f" % (accuracy_v, loss_v))
print("Test: accuracy = %f  ;  loss = %f" % (accuracy, loss))
#classifier.save("classify.h5")
# Out:
# 63/63 [==============================] - 10s 136ms/step - loss: 0.6543 - accuracy: 0.7783
# 26/26 [==============================] - 3s 127ms/step - loss: 0.6268 - accuracy: 0.7918
# Validation: accuracy = 0.791771  ;  loss_v = 0.626849
# Test: accuracy = 0.778332  ;  loss = 0.654341

# %% [markdown]
# ### _Confusion Matrix_

# %%
DIE()
from sklearn.metrics import confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    decoy = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > decoy else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

#Predicting the values from the validation dataset
Y_pred = classifier.predict(x_validate)
#Converting predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
#Converting validation observations to one hot vectors
Y_true = np.argmax(y_validate,axis = 1) 
#Computing the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)

plot_confusion_matrix(confusion_mtx, classes = range(7))
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.

# %%
model_json = classifier.to_json()
with open("classifier.json","w") as json_file:
    json_file.write(model_json)
classifier.save_weights("classifier.h5")

# %%
# imports

from keras import model_from_json 

# opening and store file in a variable

json_file = open('classifier.json','r')
loaded_model_json = json_file.read()
json_file.close()

# use Keras model_from_json to make a loaded model

loaded_model = model_from_json(loaded_model_json)

# load weights into new model

loaded_model.load_weights("classifier.h5")
print("Loaded Model from disk")

# compile and evaluate loaded model

loaded_model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [28], in <cell line: 3>()
#       1 # imports
# ----> 3 from keras import model_from_json
#       5 # opening and store file in a variable
#       7 json_file = open('classifier.json','r')
#
# ImportError: cannot import name 'model_from_json' from 'keras' (C:\Users\Lenovo\anaconda3\lib\site-packages\keras\__init__.py)

# %%
from keras.preprocessing import image
from IPython.display import display
from PIL import Image
path='C:/Users/ANUSHA/Documents/project main/Skin-Cancer-Classification-Using-CNN-Deep-Learning-Algorithm-master (1)/Skin-Cancer-Classification-Using-CNN-Deep-Learning-Algorithm-master/dataset/ISIC_0024445.jpg'
test_image1 = image.load_img(path, target_size = (64, 64))
test_image1 = image.img_to_array(test_image1)
test_image1 = np.expand_dims(test_image1, axis = 0)
result = classifier.predict(test_image1)
display(Image.open(path)) 
if result[0][0] == 1:
    print('TYPE:-\n Actinic keratoses')
elif result[0][1] == 1:
    print('TYPE:-\n Basal cell carcinoma')
elif result[0][2] == 1:
    print('TYPE:-\n Benign keratosis-like lesions')
elif result[0][3] == 1:
    print('TYPE:-\n Dermatofibroma')
elif result[0][4] ==1 :
    print('TYPE:-\n Melanoma')
elif result[0][5] == 1:
    print('TYPE:-\n Melanocytic nevi')
elif result[0][6] == 1:
    print('TYPE:-\n Vascular lesions')
